# %%
import numpy as np
import pandas as pd

# get the features from the file features.txt
features = list()
with open(r'C:\Users\hi\OneDrive\Desktop\UCI HAR Dataset\UCI HAR Dataset/features.txt') as f:
    features = [line.split()[1] for line in f.readlines()]
print('No of Features: {}'.format(len(features)))
# Out:
# No of Features: 561

# %%
import pandas as pd

X_train= pd.read_csv (r'C:\Users\hi\OneDrive\Desktop\UCI HAR Dataset\UCI HAR Dataset/train/X_train.txt',delim_whitespace = True,header= None)
X_train.columns=features
X_train['subject'] = pd.read_csv(r'C:\Users\hi\OneDrive\Desktop\UCI HAR Dataset\UCI HAR Dataset/train/subject_train.txt', header=None, squeeze=True)
y_train = pd.read_csv(r'C:\Users\hi\OneDrive\Desktop\UCI HAR Dataset\UCI HAR Dataset/train/y_train.txt', names=['Activity'], squeeze=True)
y_train_labels = y_train.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})
train = X_train
train['Activity'] = y_train
train['ActivityName'] = y_train_labels
#print(X_train)
X_train.head()
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_4960\1058305269.py:5: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   X_train['subject'] = pd.read_csv(r'C:\Users\hi\OneDrive\Desktop\UCI HAR Dataset\UCI HAR Dataset/train/subject_train.txt', header=None, squeeze=True)
# C:\Users\hi\AppData\Local\Temp\ipykernel_4960\1058305269.py:6: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   y_train = pd.read_csv(r'C:\Users\hi\OneDrive\Desktop\UCI HAR Dataset\UCI HAR Dataset/train/y_train.txt', names=['Activity'], squeeze=True)
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  angle(tBodyAccMean,gravity)  \
# 0         -0.923527         -0.934724  ...                    -0.112754
# 1         -0.957686         -0.943068  ...                     0.053477
# 2         -0.977469         -0.938692  ...                    -0.118559
# 3         -0.989302         -0.938692  ...                    -0.036788
# 4         -0.990441         -0.942469  ...                     0.123320
#
#    angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 0                              0.030400                         -0.464761
# 1                             -0.007435                         -0.732626
# 2                              0.177899                          0.100699
# 3                             -0.012892                          0.640011
# 4                              0.122542                          0.693578
#
#    angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                             -0.018446             -0.841247
# 1                              0.703511             -0.844788
# 2                              0.808529             -0.848933
# 3                             -0.485366             -0.848649
# 4                             -0.615971             -0.847865
#
#    angle(Y,gravityMean)  angle(Z,gravityMean)  subject  Activity  ActivityName
# 0              0.179941             -0.058627        1         5      STANDING
# 1              0.180289             -0.054317        1         5      STANDING
# 2              0.180637             -0.049118        1         5      STANDING
# 3              0.181935             -0.047663        1         5      STANDING
# 4              0.185151             -0.043892        1         5      STANDING
#
# [5 rows x 564 columns]

# %%
X_train.columns
# Out:
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'angle(tBodyAccMean,gravity)', 'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'subject', 'Activity',
#        'ActivityName'],
#       dtype='object', length=564)

# %%
import numpy as np
import pandas as pd

# get the features from the file features.txt
features = list()
with open(r'C:\Users\hi\OneDrive\Desktop\UCI HAR Dataset\UCI HAR Dataset/features.txt') as f:
    features = [line.split()[1] for line in f.readlines()]
print('No of Features: {}'.format(len(features)))
# Out:
# No of Features: 561

# %%
import pandas as pd

X_test = pd.read_csv(r'C:\Users\hi\OneDrive\Desktop\UCI HAR Dataset\UCI HAR Dataset/test/X_test.txt', delim_whitespace=True, header=None)

X_test.columns=features
# get y labels from the txt file
y_test = pd.read_csv(r'C:\Users\hi\OneDrive\Desktop\UCI HAR Dataset\UCI HAR Dataset/test/y_test.txt', names=['Activity'], squeeze=True)
# add subject column to the dataframe
X_test['subject'] = pd.read_csv(r'C:\Users\hi\OneDrive\Desktop\UCI HAR Dataset\UCI HAR Dataset/test/subject_test.txt', header=None, squeeze=True)

y_test_labels = y_test.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                      4:'SITTING', 5:'STANDING',6:'LAYING'})
#y_test.head()

# put all columns in a single dataframe
test = X_test
test['Activity'] = y_test
test['ActivityName'] = y_test_labels
X_test.head()
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_4960\553444098.py:7: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   y_test = pd.read_csv(r'C:\Users\hi\OneDrive\Desktop\UCI HAR Dataset\UCI HAR Dataset/test/y_test.txt', names=['Activity'], squeeze=True)
# C:\Users\hi\AppData\Local\Temp\ipykernel_4960\553444098.py:9: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   X_test['subject'] = pd.read_csv(r'C:\Users\hi\OneDrive\Desktop\UCI HAR Dataset\UCI HAR Dataset/test/subject_test.txt', header=None, squeeze=True)
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.257178          -0.023285          -0.014654         -0.938404
# 1           0.286027          -0.013163          -0.119083         -0.975415
# 2           0.275485          -0.026050          -0.118152         -0.993819
# 3           0.270298          -0.032614          -0.117520         -0.994743
# 4           0.274833          -0.027848          -0.129527         -0.993852
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.920091         -0.667683         -0.952501         -0.925249
# 1         -0.967458         -0.944958         -0.986799         -0.968401
# 2         -0.969926         -0.962748         -0.994403         -0.970735
# 3         -0.973268         -0.967091         -0.995274         -0.974471
# 4         -0.967445         -0.978295         -0.994111         -0.965953
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  angle(tBodyAccMean,gravity)  \
# 0         -0.674302         -0.894088  ...                     0.006462
# 1         -0.945823         -0.894088  ...                    -0.083495
# 2         -0.963483         -0.939260  ...                    -0.034956
# 3         -0.968897         -0.938610  ...                    -0.017067
# 4         -0.977346         -0.938610  ...                    -0.002223
#
#    angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 0                              0.162920                         -0.825886
# 1                              0.017500                         -0.434375
# 2                              0.202302                          0.064103
# 3                              0.154438                          0.340134
# 4                             -0.040046                          0.736715
#
#    angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                              0.271151             -0.720009
# 1                              0.920593             -0.698091
# 2                              0.145068             -0.702771
# 3                              0.296407             -0.698954
# 4                             -0.118545             -0.692245
#
#    angle(Y,gravityMean)  angle(Z,gravityMean)  subject  Activity  ActivityName
# 0              0.276801             -0.057978        2         5      STANDING
# 1              0.281343             -0.083898        2         5      STANDING
# 2              0.280083             -0.079346        2         5      STANDING
# 3              0.284114             -0.077108        2         5      STANDING
# 4              0.290722             -0.073857        2         5      STANDING
#
# [5 rows x 564 columns]

# %%
X_test.columns
# Out:
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'angle(tBodyAccMean,gravity)', 'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'subject', 'Activity',
#        'ActivityName'],
#       dtype='object', length=564)

# %%
#checking for duplicates
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# No of duplicates in train: 0
# No of duplicates in test : 0

# %%
#if there are duplicates 
#DataFrame.drop_duplicates(subset=None, keep=’first’, inplace=False)

# %%
#Checking for null values
print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %%
#dropna(self, axis=0, how="any", thresh=None, subset=None, inplace=False)

# %%
#Data Balance
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('white')
plt.rcParams['font.family'] = 'Dejavu Sans'

# %%
plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.show()

# %%
plt.title('No of Datapoints per Activity', fontsize=15)
sns.countplot(train.ActivityName)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
columns = train.columns

# Removing '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]', '')

train.columns = columns
test.columns = columns

test.columns
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_4960\1872868015.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   columns = columns.str.replace('[()]','')
# C:\Users\hi\AppData\Local\Temp\ipykernel_4960\1872868015.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   columns = columns.str.replace('[-]', '')
# C:\Users\hi\AppData\Local\Temp\ipykernel_4960\1872868015.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   columns = columns.str.replace('[,]', '')
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='ActivityName', size=6,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()
plt.annotate("Stationary Activities", xy=(-0.956,17), xytext=(-0.9, 23), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()
# Out:
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]

plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
plt.title('Stationary Activities(Zoomed in)')
sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
plt.axis([-1.01, -0.5, 0, 35])
plt.legend(loc='center')

plt.subplot(2,2,2)
plt.title('Moving Activities')
sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
sns.distplot(df2['tBodyAccMagmean'],color = 'blue',hist = False,label = 'Walking Up')
sns.distplot(df3['tBodyAccMagmean'],color = 'green',hist = False, label = 'Walking down')
plt.legend(loc='center right')


plt.tight_layout()
plt.show()
# Out:
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='ActivityName', y='tBodyAccMagmean',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(x='ActivityName', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %%
sns.boxplot(x='ActivityName', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.000s...
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computed neighbors for 7352 samples in 1.033s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.597464
# [t-SNE] Computed conditional probabilities in 0.016s
# [t-SNE] Iteration 50: error = 124.7378311, gradient norm = 0.0300754 (50 iterations in 1.499s)
# [t-SNE] Iteration 100: error = 106.8321915, gradient norm = 0.0271711 (50 iterations in 1.003s)
# [t-SNE] Iteration 150: error = 100.6869049, gradient norm = 0.0188309 (50 iterations in 0.941s)
# [t-SNE] Iteration 200: error = 97.3352585, gradient norm = 0.0170095 (50 iterations in 0.916s)
# [t-SNE] Iteration 250: error = 95.0292664, gradient norm = 0.0157926 (50 iterations in 0.948s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 95.029266
# [t-SNE] Iteration 300: error = 4.1143942, gradient norm = 0.0015636 (50 iterations in 0.893s)
# [t-SNE] Iteration 350: error = 3.2018492, gradient norm = 0.0010135 (50 iterations in 0.924s)
# [t-SNE] Iteration 400: error = 2.7731893, gradient norm = 0.0007206 (50 iterations in 0.956s)
# [t-SNE] Iteration 450: error = 2.5093586, gradient norm = 0.0005671 (50 iterations in 0.951s)
# [t-SNE] Iteration 500: error = 2.3261206, gradient norm = 0.0004852 (50 iterations in 0.940s)
# [t-SNE] Iteration 550: error = 2.1882050, gradient norm = 0.0004168 (50 iterations in 0.988s)
# [t-SNE] Iteration 600: error = 2.0791044, gradient norm = 0.0003656 (50 iterations in 1.025s)
# [t-SNE] Iteration 650: error = 1.9890209, gradient norm = 0.0003342 (50 iterations in 0.956s)
# [t-SNE] Iteration 700: error = 1.9133676, gradient norm = 0.0002998 (50 iterations in 0.951s)
# [t-SNE] Iteration 750: error = 1.8483429, gradient norm = 0.0002780 (50 iterations in 0.940s)
# [t-SNE] Iteration 800: error = 1.7917773, gradient norm = 0.0002584 (50 iterations in 1.010s)
# [t-SNE] Iteration 850: error = 1.7420030, gradient norm = 0.0002384 (50 iterations in 1.206s)
# [t-SNE] Iteration 900: error = 1.6973760, gradient norm = 0.0002238 (50 iterations in 1.253s)
# [t-SNE] Iteration 950: error = 1.6571923, gradient norm = 0.0002121 (50 iterations in 1.252s)
# [t-SNE] Iteration 1000: error = 1.6209192, gradient norm = 0.0002013 (50 iterations in 1.229s)
# [t-SNE] KL divergence after 1000 iterations: 1.620919
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.000s...
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computed neighbors for 7352 samples in 1.201s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961446
# [t-SNE] Computed conditional probabilities in 0.016s
# [t-SNE] Iteration 50: error = 114.0045471, gradient norm = 0.0213408 (50 iterations in 1.842s)
# [t-SNE] Iteration 100: error = 97.6338120, gradient norm = 0.0156826 (50 iterations in 1.792s)
# [t-SNE] Iteration 150: error = 92.9533310, gradient norm = 0.0090123 (50 iterations in 1.451s)
# [t-SNE] Iteration 200: error = 91.0048218, gradient norm = 0.0071533 (50 iterations in 1.333s)
# [t-SNE] Iteration 250: error = 89.8472595, gradient norm = 0.0048174 (50 iterations in 1.439s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 89.847260
# [t-SNE] Iteration 300: error = 3.5645154, gradient norm = 0.0014638 (50 iterations in 1.330s)
# [t-SNE] Iteration 350: error = 2.8085439, gradient norm = 0.0007494 (50 iterations in 1.393s)
# [t-SNE] Iteration 400: error = 2.4289744, gradient norm = 0.0005265 (50 iterations in 1.319s)
# [t-SNE] Iteration 450: error = 2.2123826, gradient norm = 0.0004037 (50 iterations in 1.332s)
# [t-SNE] Iteration 500: error = 2.0675197, gradient norm = 0.0003300 (50 iterations in 1.272s)
# [t-SNE] Iteration 550: error = 1.9623628, gradient norm = 0.0002858 (50 iterations in 1.228s)
# [t-SNE] Iteration 600: error = 1.8817616, gradient norm = 0.0002456 (50 iterations in 1.199s)
# [t-SNE] Iteration 650: error = 1.8166864, gradient norm = 0.0002203 (50 iterations in 1.229s)
# [t-SNE] Iteration 700: error = 1.7629120, gradient norm = 0.0001982 (50 iterations in 1.198s)
# [t-SNE] Iteration 750: error = 1.7178353, gradient norm = 0.0001808 (50 iterations in 1.262s)
# [t-SNE] Iteration 800: error = 1.6789842, gradient norm = 0.0001650 (50 iterations in 1.183s)
# [t-SNE] Iteration 850: error = 1.6451836, gradient norm = 0.0001540 (50 iterations in 1.194s)
# [t-SNE] Iteration 900: error = 1.6154079, gradient norm = 0.0001440 (50 iterations in 1.223s)
# [t-SNE] Iteration 950: error = 1.5889509, gradient norm = 0.0001342 (50 iterations in 1.262s)
# [t-SNE] Iteration 1000: error = 1.5652250, gradient norm = 0.0001256 (50 iterations in 1.215s)
# [t-SNE] KL divergence after 1000 iterations: 1.565225
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.004s...
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computed neighbors for 7352 samples in 1.178s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133827
# [t-SNE] Computed conditional probabilities in 0.047s
# [t-SNE] Iteration 50: error = 105.8052521, gradient norm = 0.0212403 (50 iterations in 1.701s)
# [t-SNE] Iteration 100: error = 90.4062042, gradient norm = 0.0101137 (50 iterations in 1.672s)
# [t-SNE] Iteration 150: error = 87.4388580, gradient norm = 0.0068930 (50 iterations in 1.513s)
# [t-SNE] Iteration 200: error = 86.2248459, gradient norm = 0.0038370 (50 iterations in 1.463s)
# [t-SNE] Iteration 250: error = 85.5149460, gradient norm = 0.0039227 (50 iterations in 1.453s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.514946
# [t-SNE] Iteration 300: error = 3.1347227, gradient norm = 0.0013946 (50 iterations in 1.323s)
# [t-SNE] Iteration 350: error = 2.4901011, gradient norm = 0.0006474 (50 iterations in 1.416s)
# [t-SNE] Iteration 400: error = 2.1703649, gradient norm = 0.0004225 (50 iterations in 1.403s)
# [t-SNE] Iteration 450: error = 1.9855075, gradient norm = 0.0003137 (50 iterations in 1.268s)
# [t-SNE] Iteration 500: error = 1.8671057, gradient norm = 0.0002510 (50 iterations in 1.331s)
# [t-SNE] Iteration 550: error = 1.7838291, gradient norm = 0.0002100 (50 iterations in 1.258s)
# [t-SNE] Iteration 600: error = 1.7212634, gradient norm = 0.0001822 (50 iterations in 1.290s)
# [t-SNE] Iteration 650: error = 1.6722248, gradient norm = 0.0001611 (50 iterations in 1.492s)
# [t-SNE] Iteration 700: error = 1.6327827, gradient norm = 0.0001429 (50 iterations in 1.409s)
# [t-SNE] Iteration 750: error = 1.6001065, gradient norm = 0.0001295 (50 iterations in 1.326s)
# [t-SNE] Iteration 800: error = 1.5725595, gradient norm = 0.0001195 (50 iterations in 1.238s)
# [t-SNE] Iteration 850: error = 1.5493007, gradient norm = 0.0001106 (50 iterations in 1.307s)
# [t-SNE] Iteration 900: error = 1.5293783, gradient norm = 0.0001026 (50 iterations in 1.269s)
# [t-SNE] Iteration 950: error = 1.5119777, gradient norm = 0.0000965 (50 iterations in 1.260s)
# [t-SNE] Iteration 1000: error = 1.4968214, gradient norm = 0.0000926 (50 iterations in 1.261s)
# [t-SNE] KL divergence after 1000 iterations: 1.496821
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.008s...
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computed neighbors for 7352 samples in 1.185s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274336
# [t-SNE] Computed conditional probabilities in 0.094s
# [t-SNE] Iteration 50: error = 97.2864838, gradient norm = 0.0241238 (50 iterations in 1.886s)
# [t-SNE] Iteration 100: error = 84.0590668, gradient norm = 0.0059715 (50 iterations in 1.754s)
# [t-SNE] Iteration 150: error = 81.9152985, gradient norm = 0.0035922 (50 iterations in 1.902s)
# [t-SNE] Iteration 200: error = 81.1719513, gradient norm = 0.0026157 (50 iterations in 1.802s)
# [t-SNE] Iteration 250: error = 80.7843094, gradient norm = 0.0019502 (50 iterations in 1.667s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.784309
# [t-SNE] Iteration 300: error = 2.6981666, gradient norm = 0.0013020 (50 iterations in 1.471s)
# [t-SNE] Iteration 350: error = 2.1654034, gradient norm = 0.0005738 (50 iterations in 1.394s)
# [t-SNE] Iteration 400: error = 1.9171203, gradient norm = 0.0003467 (50 iterations in 1.377s)
# [t-SNE] Iteration 450: error = 1.7708256, gradient norm = 0.0002460 (50 iterations in 1.392s)
# [t-SNE] Iteration 500: error = 1.6770482, gradient norm = 0.0001921 (50 iterations in 1.417s)
# [t-SNE] Iteration 550: error = 1.6126888, gradient norm = 0.0001574 (50 iterations in 1.427s)
# [t-SNE] Iteration 600: error = 1.5663630, gradient norm = 0.0001344 (50 iterations in 1.421s)
# [t-SNE] Iteration 650: error = 1.5309134, gradient norm = 0.0001174 (50 iterations in 1.501s)
# [t-SNE] Iteration 700: error = 1.5030007, gradient norm = 0.0001048 (50 iterations in 1.600s)
# [t-SNE] Iteration 750: error = 1.4807640, gradient norm = 0.0000945 (50 iterations in 1.643s)
# [t-SNE] Iteration 800: error = 1.4629252, gradient norm = 0.0000890 (50 iterations in 1.558s)
# [t-SNE] Iteration 850: error = 1.4482095, gradient norm = 0.0000826 (50 iterations in 1.649s)
# [t-SNE] Iteration 900: error = 1.4361566, gradient norm = 0.0000774 (50 iterations in 1.608s)
# [t-SNE] Iteration 950: error = 1.4257870, gradient norm = 0.0000745 (50 iterations in 1.585s)
# [t-SNE] Iteration 1000: error = 1.4173211, gradient norm = 0.0000724 (50 iterations in 1.586s)
# [t-SNE] KL divergence after 1000 iterations: 1.417321
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.000s...
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computed neighbors for 7352 samples in 1.368s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.264s
# [t-SNE] Iteration 50: error = 86.9418411, gradient norm = 0.0132376 (50 iterations in 4.049s)
# [t-SNE] Iteration 100: error = 75.6948929, gradient norm = 0.0046828 (50 iterations in 3.249s)
# [t-SNE] Iteration 150: error = 74.7139740, gradient norm = 0.0021216 (50 iterations in 2.551s)
# [t-SNE] Iteration 200: error = 74.3309021, gradient norm = 0.0023802 (50 iterations in 3.132s)
# [t-SNE] Iteration 250: error = 74.1429749, gradient norm = 0.0014176 (50 iterations in 2.589s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.142975
# [t-SNE] Iteration 300: error = 2.1546001, gradient norm = 0.0011793 (50 iterations in 2.254s)
# [t-SNE] Iteration 350: error = 1.7583894, gradient norm = 0.0004890 (50 iterations in 1.979s)
# [t-SNE] Iteration 400: error = 1.5892910, gradient norm = 0.0002826 (50 iterations in 1.870s)
# [t-SNE] Iteration 450: error = 1.4953779, gradient norm = 0.0001893 (50 iterations in 1.926s)
# [t-SNE] Iteration 500: error = 1.4352753, gradient norm = 0.0001409 (50 iterations in 2.101s)
# [t-SNE] Iteration 550: error = 1.3936758, gradient norm = 0.0001130 (50 iterations in 2.236s)
# [t-SNE] Iteration 600: error = 1.3639982, gradient norm = 0.0000937 (50 iterations in 2.074s)
# [t-SNE] Iteration 650: error = 1.3423142, gradient norm = 0.0000824 (50 iterations in 2.018s)
# [t-SNE] Iteration 700: error = 1.3262857, gradient norm = 0.0000721 (50 iterations in 1.951s)
# [t-SNE] Iteration 750: error = 1.3140228, gradient norm = 0.0000659 (50 iterations in 2.243s)
# [t-SNE] Iteration 800: error = 1.3043711, gradient norm = 0.0000630 (50 iterations in 2.313s)
# [t-SNE] Iteration 850: error = 1.2968920, gradient norm = 0.0000566 (50 iterations in 2.051s)
# [t-SNE] Iteration 900: error = 1.2907565, gradient norm = 0.0000547 (50 iterations in 2.104s)
# [t-SNE] Iteration 950: error = 1.2859422, gradient norm = 0.0000506 (50 iterations in 2.066s)
# [t-SNE] Iteration 1000: error = 1.2818964, gradient norm = 0.0000502 (50 iterations in 2.123s)
# [t-SNE] KL divergence after 1000 iterations: 1.281896
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done

# %%
print(X_train)
# Out:
#       tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0          0.288585      -0.020294      -0.132905     -0.995279     -0.983111
# 1          0.278419      -0.016411      -0.123520     -0.998245     -0.975300
# 2          0.279653      -0.019467      -0.113462     -0.995380     -0.967187
# 3          0.279174      -0.026201      -0.123283     -0.996091     -0.983403
# 4          0.276629      -0.016570      -0.115362     -0.998139     -0.980817
# ...             ...            ...            ...           ...           ...
# 7347       0.299665      -0.057193      -0.181233     -0.195387      0.039905
# 7348       0.273853      -0.007749      -0.147468     -0.235309      0.004816
# 7349       0.273387      -0.017011      -0.045022     -0.218218     -0.103822
# 7350       0.289654      -0.018843      -0.158281     -0.219139     -0.111412
# 7351       0.351503      -0.012423      -0.203867     -0.269270     -0.087212
#
#       tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  \
# 0        -0.913526     -0.995112     -0.983185     -0.923527     -0.934724
# 1        -0.960322     -0.998807     -0.974914     -0.957686     -0.943068
# 2        -0.978944     -0.996520     -0.963668     -0.977469     -0.938692
# 3        -0.990675     -0.997099     -0.982750     -0.989302     -0.938692
# 4        -0.990482     -0.998321     -0.979672     -0.990441     -0.942469
# ...            ...           ...           ...           ...           ...
# 7347      0.077078     -0.282301      0.043616      0.060410      0.210795
# 7348      0.059280     -0.322552     -0.029456      0.080585      0.117440
# 7349      0.274533     -0.304515     -0.098913      0.332584      0.043999
# 7350      0.268893     -0.310487     -0.068200      0.319473      0.101702
# 7351      0.177404     -0.377404     -0.038678      0.229430      0.269013
#
#       ...  angletBodyAccMeangravity  angletBodyAccJerkMeangravityMean  \
# 0     ...                 -0.112754                          0.030400
# 1     ...                  0.053477                         -0.007435
# 2     ...                 -0.118559                          0.177899
# 3     ...                 -0.036788                         -0.012892
# 4     ...                  0.123320                          0.122542
# ...   ...                       ...                               ...
# 7347  ...                 -0.190437                          0.829718
# 7348  ...                  0.064907                          0.875679
# 7349  ...                  0.052806                         -0.266724
# 7350  ...                 -0.101360                          0.700740
# 7351  ...                 -0.280088                         -0.007739
#
#       angletBodyGyroMeangravityMean  angletBodyGyroJerkMeangravityMean  \
# 0                         -0.464761                          -0.018446
# 1                         -0.732626                           0.703511
# 2                          0.100699                           0.808529
# 3                          0.640011                          -0.485366
# 4                          0.693578                          -0.615971
# ...                             ...                                ...
# 7347                       0.206972                          -0.425619
# 7348                      -0.879033                           0.400219
# 7349                       0.864404                           0.701169
# 7350                       0.936674                          -0.589479
# 7351                      -0.056088                          -0.616956
#
#       angleXgravityMean  angleYgravityMean  angleZgravityMean  subject  \
# 0             -0.841247           0.179941          -0.058627        1
# 1             -0.844788           0.180289          -0.054317        1
# 2             -0.848933           0.180637          -0.049118        1
# 3             -0.848649           0.181935          -0.047663        1
# 4             -0.847865           0.185151          -0.043892        1
# ...                 ...                ...                ...      ...
# 7347          -0.791883           0.238604           0.049819       30
# 7348          -0.771840           0.252676           0.050053       30
# 7349          -0.779133           0.249145           0.040811       30
# 7350          -0.785181           0.246432           0.025339       30
# 7351          -0.783267           0.246809           0.036695       30
#
#       Activity      ActivityName
# 0            5          STANDING
# 1            5          STANDING
# 2            5          STANDING
# 3            5          STANDING
# 4            5          STANDING
# ...        ...               ...
# 7347         2  WALKING_UPSTAIRS
# 7348         2  WALKING_UPSTAIRS
# 7349         2  WALKING_UPSTAIRS
# 7350         2  WALKING_UPSTAIRS
# 7351         2  WALKING_UPSTAIRS
#
# [7352 rows x 564 columns]

# %%
import numpy as np
import pandas as pd

# %%
#train = pd.read_csv('csv_files/train.csv')
#test = pd.read_csv('csv_files/test.csv')
print(train.shape, test.shape)
# Out:
# (7352, 564) (2947, 564)

# %%
train.head(3)
# Out:
#    tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0       0.288585      -0.020294      -0.132905     -0.995279     -0.983111
# 1       0.278419      -0.016411      -0.123520     -0.998245     -0.975300
# 2       0.279653      -0.019467      -0.113462     -0.995380     -0.967187
#
#    tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  ...  \
# 0     -0.913526     -0.995112     -0.983185     -0.923527     -0.934724  ...
# 1     -0.960322     -0.998807     -0.974914     -0.957686     -0.943068  ...
# 2     -0.978944     -0.996520     -0.963668     -0.977469     -0.938692  ...
#
#    angletBodyAccMeangravity  angletBodyAccJerkMeangravityMean  \
# 0                 -0.112754                          0.030400
# 1                  0.053477                         -0.007435
# 2                 -0.118559                          0.177899
#
#    angletBodyGyroMeangravityMean  angletBodyGyroJerkMeangravityMean  \
# 0                      -0.464761                          -0.018446
# 1                      -0.732626                           0.703511
# 2                       0.100699                           0.808529
#
#    angleXgravityMean  angleYgravityMean  angleZgravityMean  subject  Activity  \
# 0          -0.841247           0.179941          -0.058627        1         5
# 1          -0.844788           0.180289          -0.054317        1         5
# 2          -0.848933           0.180637          -0.049118        1         5
#
#    ActivityName
# 0      STANDING
# 1      STANDING
# 2      STANDING
#
# [3 rows x 564 columns]

# %%
X_train = train.drop(['subject', 'Activity', 'ActivityName'], axis=1)
y_train = train.ActivityName

# %%
# get X_test and y_test from test csv file
X_test = test.drop(['subject', 'Activity', 'ActivityName'], axis=1)
y_test = test.ActivityName

# %%
print('X_train and y_train : ({},{})'.format(X_train.shape, y_train.shape))
print('X_test  and y_test  : ({},{})'.format(X_test.shape, y_test.shape))
# Out:
# X_train and y_train : ((7352, 561),(7352,))
# X_test  and y_test  : ((2947, 561),(2947,))

# %%
labels=['LAYING', 'SITTING','STANDING','WALKING','WALKING_DOWNSTAIRS','WALKING_UPSTAIRS']

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

# %%
lda = LDA()
X_train = lda.fit_transform(X_train, y_train)
X_test = lda.transform(X_test)

# %%
# Displaying the shape of training and testing data

print('X_train and y_train : ({},{})'.format(X_train.shape, y_train.shape))
print('X_test  and y_test  : ({},{})'.format(X_test.shape, y_test.shape))
# Out:
# X_train and y_train : ((7352, 5),(7352,))
# X_test  and y_test  : ((2947, 5),(2947,))

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# %matplotlib inline

# %%
from IPython.display import Markdown, display

def printmd(string, color=None):
    colorstr = "<span style='color:{}'>{}</span>".format(color, string)
    display(Markdown(colorstr))

# %%
def plot_confusion_matrix(cm, classes,
                         normalize=False,
                         title='Confusion Matrix',
                         cmap = plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')

# %%
from datetime import datetime
def perform_model(model, X_train, y_train, X_test, y_test, class_labels, cm_normalize=True, \
                 print_cm=True, cm_cmap=plt.cm.Greens):
    
    
    # Let's create an empty dictionary to be returned by the function
    results = dict()
    
    # Let's calculate & print the total training time
    
    train_start_time = datetime.now()
    model.fit(X_train, y_train)
    train_end_time = datetime.now()
    results['training_time'] =  train_end_time - train_start_time
    printmd('Training_time(HH:MM:SS.ms) - {}'.format(results['training_time']), color='blue')
        
    # Let's calculate & print the test time
    
    test_start_time = datetime.now()
    y_pred = model.predict(X_test)
    test_end_time = datetime.now()
    results['testing_time'] = test_end_time - test_start_time
    printmd('testing time(HH:MM:SS:ms) - {}'.format(results['testing_time']), color='blue')
    results['predicted'] = y_pred
   
    # Let's calculate the Accuracy of Model
    
    accuracy = metrics.accuracy_score(y_true=y_test, y_pred=y_pred)
    results['accuracy'] = accuracy
    printmd('**Accuracy:**', color='blue')
    print('{}'.format(accuracy))
        
    # Let's get the Confusion Matrix
    
    cm = metrics.confusion_matrix(y_test, y_pred)
    
    # Plotting Confusion Matrix
    
    printmd('**Confusion Matrix:**', color='blue')
    plt.figure(figsize=(8,8))
    plt.grid(b=False)
    plot_confusion_matrix(cm, classes=labels, title='Normalized confusion matrix', cmap=plt.cm.YlGn, )
    plt.show()
        
    # Plotting Normalized Confusion Matrix
    
    printmd('**Normalized Confusion Matrix:**', color='blue')
    plt.figure(figsize=(8,8))
    plt.grid(b=False)
    plot_confusion_matrix(cm, classes=class_labels, normalize=True, title='Normalized confusion matrix', cmap = cm_cmap)
    plt.show()
    
    # PLotting classification report
    
    printmd('**Classifiction Report**', color='blue')
    classification_report = metrics.classification_report(y_test, y_pred)
    results['classification_report'] = classification_report
    print(classification_report)
    
    # Adding the trained model to the results
    
    results['model'] = model
    
    return results

# %%
def print_grid_search_attributes(model):
    
    # Let's print the best estimator that gave highest score
    
    printmd('**Best Estimator:**', color='blue')
    print('{}\n'.format(model.best_estimator_))


    # Let's print the best parameters that gave best results
    
    printmd('**Best parameters:**', color='blue')
    print('{}\n'.format(model.best_params_))


    #  Let's print the number of cross validation splits
    
    printmd('**Number of CrossValidation sets:**', color='blue')
    print('{}\n'.format(model.n_splits_))


    # Let's print the Best score of the best estimator
    
    printmd('**Best Score:**', color='blue')
    print('{}\n'.format(model.best_score_))

# %%
# Importing necessary libraries

from sklearn import linear_model
from sklearn import metrics

from sklearn.model_selection import GridSearchCV

# %%
labels=['Laying', 'Sitting','Standing','Walking','Walking_Downstairs','Walking_Upstairs']

# %%
# Let's define the parameters to be tuned

parameters = {'C':[20, 25, 30, 35, 40], 'penalty':['l1', 'l2']}

# Let's initiate the model

log_reg = linear_model.LogisticRegression()
log_reg_grid = GridSearchCV(log_reg, param_grid=parameters, verbose=1, n_jobs=-1)
log_reg_grid_results =  perform_model(log_reg_grid, X_train, y_train, X_test, y_test, class_labels=labels)

# Printing the best attributes of the model 

print_grid_search_attributes(log_reg_grid_results['model'])
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 25 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 25 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [       nan 0.9851746         nan 0.98531056        nan 0.98503855
#         nan 0.98571863        nan 0.98531056]
#   warnings.warn(
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# <span style='color:blue'>Training_time(HH:MM:SS.ms) - 0:00:02.121381</span>
# <span style='color:blue'>testing time(HH:MM:SS:ms) - 0:00:00</span>
# <span style='color:blue'>**Accuracy:**</span>
# 0.9630132337970818
# <span style='color:blue'>**Confusion Matrix:**</span>
# C:\Users\hi\AppData\Local\Temp\ipykernel_4960\1948089132.py:41: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=False)
# <span style='color:blue'>**Normalized Confusion Matrix:**</span>
# C:\Users\hi\AppData\Local\Temp\ipykernel_4960\1948089132.py:49: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=False)
# <span style='color:blue'>**Classifiction Report**</span>
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.96      0.88      0.91       491
#           STANDING       0.90      0.96      0.93       532
#            WALKING       0.97      0.99      0.98       496
# WALKING_DOWNSTAIRS       1.00      0.98      0.99       420
#   WALKING_UPSTAIRS       0.97      0.97      0.97       471
#
#           accuracy                           0.96      2947
#          macro avg       0.97      0.96      0.96      2947
#       weighted avg       0.96      0.96      0.96      2947
# <span style='color:blue'>**Best Estimator:**</span>
# LogisticRegression(C=35)
# <span style='color:blue'>**Best parameters:**</span>
# {'C': 35, 'penalty': 'l2'}
# <span style='color:blue'>**Number of CrossValidation sets:**</span>
# 5
# <span style='color:blue'>**Best Score:**</span>
# 0.9857186327964225

# %%
# Importing Necessary libraries

from sklearn.svm import LinearSVC

# %%
# Let's define the parameters to be tuned

parameters = {'C':[0.25, 0.5, 1, 2, 4, 8]}

# Let's initiate the model

lin_svc = LinearSVC()
lin_svc_grid = GridSearchCV(lin_svc, param_grid=parameters, verbose=1, n_jobs=-1)
lin_svc_grid_results = perform_model(lin_svc_grid, X_train, y_train, X_test, y_test, class_labels=labels)

# Printing the best attributes of the model 

print_grid_search_attributes(lin_svc_grid_results['model'])
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# C:\Users\hi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# <span style='color:blue'>Training_time(HH:MM:SS.ms) - 0:00:00.640711</span>
# <span style='color:blue'>testing time(HH:MM:SS:ms) - 0:00:00</span>
# <span style='color:blue'>**Accuracy:**</span>
# 0.9653885307091958
# <span style='color:blue'>**Confusion Matrix:**</span>
# C:\Users\hi\AppData\Local\Temp\ipykernel_4960\1948089132.py:41: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=False)
# <span style='color:blue'>**Normalized Confusion Matrix:**</span>
# C:\Users\hi\AppData\Local\Temp\ipykernel_4960\1948089132.py:49: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=False)
# <span style='color:blue'>**Classifiction Report**</span>
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.93      0.92      0.93       491
#           STANDING       0.93      0.94      0.94       532
#            WALKING       0.96      0.99      0.98       496
# WALKING_DOWNSTAIRS       0.99      0.99      0.99       420
#   WALKING_UPSTAIRS       0.98      0.94      0.96       471
#
#           accuracy                           0.97      2947
#          macro avg       0.97      0.97      0.97      2947
#       weighted avg       0.97      0.97      0.97      2947
# <span style='color:blue'>**Best Estimator:**</span>
# LinearSVC(C=4)
# <span style='color:blue'>**Best parameters:**</span>
# {'C': 4}
# <span style='color:blue'>**Number of CrossValidation sets:**</span>
# 5
# <span style='color:blue'>**Best Score:**</span>
# 0.9859909266221785

# %%
# Importing Libraries

from sklearn.svm import SVC

# %%
# Let's define the parameters to be tuned

parameters = {'C':[0.125, 0.25, 0.5, 1], 'gamma':[0.01, 0.1, 1, 2]}

# Let's initiate the model

rbf_svc = SVC(kernel='rbf')
rbf_svc_grid = GridSearchCV(rbf_svc, param_grid=parameters)
rbf_svc_grid_results = perform_model(rbf_svc_grid, X_train, y_train, X_test, y_test, class_labels=labels)

# Printing the best attributes of the model 

print_grid_search_attributes(rbf_svc_grid_results['model'])
# Out:
# <span style='color:blue'>Training_time(HH:MM:SS.ms) - 0:01:07.001185</span>
# <span style='color:blue'>testing time(HH:MM:SS:ms) - 0:00:00.166049</span>
# <span style='color:blue'>**Accuracy:**</span>
# 0.9684424838819138
# <span style='color:blue'>**Confusion Matrix:**</span>
# C:\Users\hi\AppData\Local\Temp\ipykernel_4960\1948089132.py:41: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=False)
# <span style='color:blue'>**Normalized Confusion Matrix:**</span>
# C:\Users\hi\AppData\Local\Temp\ipykernel_4960\1948089132.py:49: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=False)
# <span style='color:blue'>**Classifiction Report**</span>
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.95      0.91      0.93       491
#           STANDING       0.92      0.96      0.94       532
#            WALKING       0.98      0.99      0.98       496
# WALKING_DOWNSTAIRS       1.00      0.98      0.99       420
#   WALKING_UPSTAIRS       0.97      0.98      0.97       471
#
#           accuracy                           0.97      2947
#          macro avg       0.97      0.97      0.97      2947
#       weighted avg       0.97      0.97      0.97      2947
# <span style='color:blue'>**Best Estimator:**</span>
# SVC(C=0.125, gamma=0.1)
# <span style='color:blue'>**Best parameters:**</span>
# {'C': 0.125, 'gamma': 0.1}
# <span style='color:blue'>**Number of CrossValidation sets:**</span>
# 5
# <span style='color:blue'>**Best Score:**</span>
# 0.9861267035706194

# %%
# Importing libraries

from sklearn.tree import DecisionTreeClassifier
# Let's define the parameters to be tuned

# %%
parameters = {'max_depth':np.arange(4,10,1)}

# Let's initiate the model

dtree = DecisionTreeClassifier()
dtree_grid = GridSearchCV(dtree, param_grid=parameters, verbose=1, n_jobs=-1)
dtree_grid_results = perform_model(dtree_grid, X_train, y_train, X_test, y_test, class_labels=labels)

# Printing the best attributes of the model 

print_grid_search_attributes(dtree_grid_results['model'])
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# <span style='color:blue'>Training_time(HH:MM:SS.ms) - 0:00:02.454739</span>
# <span style='color:blue'>testing time(HH:MM:SS:ms) - 0:00:00</span>
# <span style='color:blue'>**Accuracy:**</span>
# 0.9514760773668137
# <span style='color:blue'>**Confusion Matrix:**</span>
# C:\Users\hi\AppData\Local\Temp\ipykernel_4960\1948089132.py:41: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=False)
# <span style='color:blue'>**Normalized Confusion Matrix:**</span>
# C:\Users\hi\AppData\Local\Temp\ipykernel_4960\1948089132.py:49: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=False)
# <span style='color:blue'>**Classifiction Report**</span>
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.94      0.87      0.90       491
#           STANDING       0.89      0.95      0.92       532
#            WALKING       0.92      0.99      0.96       496
# WALKING_DOWNSTAIRS       1.00      0.94      0.97       420
#   WALKING_UPSTAIRS       0.98      0.95      0.96       471
#
#           accuracy                           0.95      2947
#          macro avg       0.95      0.95      0.95      2947
#       weighted avg       0.95      0.95      0.95      2947
# <span style='color:blue'>**Best Estimator:**</span>
# DecisionTreeClassifier(max_depth=5)
# <span style='color:blue'>**Best parameters:**</span>
# {'max_depth': 5}
# <span style='color:blue'>**Number of CrossValidation sets:**</span>
# 5
# <span style='color:blue'>**Best Score:**</span>
# 0.9829986542543597

# %%
# Importing libraries

from sklearn.ensemble import RandomForestClassifier

# %%
# Let's define the parameters to be tuned

parameters = {'n_estimators': np.arange(10,201,20), 'max_depth':np.arange(4,15,2)}

# Let's initiate the model

rfc = RandomForestClassifier()
rfc_grid = GridSearchCV(rfc, param_grid=parameters, n_jobs=-1)
rfc_grid_results = perform_model(rfc_grid, X_train, y_train, X_test, y_test, class_labels=labels)

# Printing the best attributes of the model 

print_grid_search_attributes(rfc_grid_results['model'])
# Out:
# <span style='color:blue'>Training_time(HH:MM:SS.ms) - 0:00:40.021218</span>
# <span style='color:blue'>testing time(HH:MM:SS:ms) - 0:00:00.036586</span>
# <span style='color:blue'>**Accuracy:**</span>
# 0.9623345775364778
# <span style='color:blue'>**Confusion Matrix:**</span>
# C:\Users\hi\AppData\Local\Temp\ipykernel_4960\1948089132.py:41: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=False)
# <span style='color:blue'>**Normalized Confusion Matrix:**</span>
# C:\Users\hi\AppData\Local\Temp\ipykernel_4960\1948089132.py:49: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=False)
# <span style='color:blue'>**Classifiction Report**</span>
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.96      0.86      0.91       491
#           STANDING       0.88      0.97      0.92       532
#            WALKING       0.97      0.99      0.98       496
# WALKING_DOWNSTAIRS       1.00      0.98      0.99       420
#   WALKING_UPSTAIRS       0.98      0.97      0.98       471
#
#           accuracy                           0.96      2947
#          macro avg       0.97      0.96      0.96      2947
#       weighted avg       0.96      0.96      0.96      2947
# <span style='color:blue'>**Best Estimator:**</span>
# RandomForestClassifier(max_depth=6, n_estimators=150)
# <span style='color:blue'>**Best parameters:**</span>
# {'max_depth': 6, 'n_estimators': 150}
# <span style='color:blue'>**Number of CrossValidation sets:**</span>
# 5
# <span style='color:blue'>**Best Score:**</span>
# 0.9858545947270819

# %%
# Importing Libraries

from sklearn.ensemble import GradientBoostingClassifier

# %%
# Let's define the parameters to be tuned

parameters = {'n_estimators': np.arange(120,150,10), 'max_depth':np.arange(3,7,1)}

# Let's initiate the model

gbdt = GradientBoostingClassifier()
gbdt_grid = GridSearchCV(gbdt, param_grid=parameters, n_jobs=-1)
gbdt_grid_results = perform_model(gbdt_grid, X_train, y_train, X_test, y_test, class_labels=labels)

# Printing the best attributes of the model 

print_grid_search_attributes(gbdt_grid_results['model'])
# Out:
# <span style='color:blue'>Training_time(HH:MM:SS.ms) - 0:03:07.803549</span>
# <span style='color:blue'>testing time(HH:MM:SS:ms) - 0:00:00.017926</span>
# <span style='color:blue'>**Accuracy:**</span>
# 0.9545300305395318
# <span style='color:blue'>**Confusion Matrix:**</span>
# C:\Users\hi\AppData\Local\Temp\ipykernel_4960\1948089132.py:41: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=False)
# <span style='color:blue'>**Normalized Confusion Matrix:**</span>
# C:\Users\hi\AppData\Local\Temp\ipykernel_4960\1948089132.py:49: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=False)
# <span style='color:blue'>**Classifiction Report**</span>
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.94      0.87      0.91       491
#           STANDING       0.86      0.97      0.91       532
#            WALKING       0.98      0.99      0.98       496
# WALKING_DOWNSTAIRS       1.00      0.92      0.96       420
#   WALKING_UPSTAIRS       0.98      0.97      0.97       471
#
#           accuracy                           0.95      2947
#          macro avg       0.96      0.95      0.95      2947
#       weighted avg       0.96      0.95      0.95      2947
# <span style='color:blue'>**Best Estimator:**</span>
# GradientBoostingClassifier(n_estimators=140)
# <span style='color:blue'>**Best parameters:**</span>
# {'max_depth': 3, 'n_estimators': 140}
# <span style='color:blue'>**Number of CrossValidation sets:**</span>
# 5
# <span style='color:blue'>**Best Score:**</span>
# 0.9804136202407543

# %%
print('\n                     Accuracy     Error')
print('                     ----------   --------')
print('Logistic Regression : {:.04}%      {:.04}%'.format(log_reg_grid_results['accuracy'] * 100,\
                                                  100-(log_reg_grid_results['accuracy'] * 100)))

print('Linear SVC          : {:.04}%       {:.04}% '.format(lin_svc_grid_results['accuracy'] * 100,\
                                                        100-(lin_svc_grid_results['accuracy'] * 100)))

print('RBF SVM classifier  : {:.04}%      {:.04}% '.format(rbf_svc_grid_results['accuracy'] * 100,\
                                                          100-(rbf_svc_grid_results['accuracy'] * 100)))

print('Decision Tree       : {:.04}%      {:.04}% '.format(dtree_grid_results['accuracy'] * 100,\
                                                        100-(dtree_grid_results['accuracy'] * 100)))

print('Random Forest       : {:.04}%       {:.04}% '.format(rfc_grid_results['accuracy'] * 100,\
                                                           100-(rfc_grid_results['accuracy'] * 100)))
print('GradientBoosting    : {:.04}%      {:.04}% '.format(gbdt_grid_results['accuracy'] * 100,\
                                                        100-(gbdt_grid_results['accuracy'] * 100)))
# Out:
#                      Accuracy     Error
#                      ----------   --------
# Logistic Regression : 96.3%      3.699%
# Linear SVC          : 96.54%       3.461%
# RBF SVM classifier  : 96.84%      3.156%
# Decision Tree       : 95.15%      4.852%
# Random Forest       : 96.23%       3.767%
# GradientBoosting    : 95.45%      4.547%
